# %%
import yfinance as yf
import numpy as np
import pandas as pd
import datetime

# %%
AAPL = yf.download(tickers='AAPL',start ='2020-5-31', end ='2021-10-10')
AAPL
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-01   79.437500   80.587502   79.302498   80.462502   79.804390
# 2020-06-02   80.187500   80.860001   79.732498   80.834999   80.173859
# 2020-06-03   81.165001   81.550003   80.574997   81.279999   80.615211
# 2020-06-04   81.097504   81.404999   80.195000   80.580002   79.920937
# 2020-06-05   80.837502   82.937500   80.807503   82.875000   82.197174
# ...                ...         ...         ...         ...         ...
# 2021-10-04  141.759995  142.210007  138.270004  139.139999  139.139999
# 2021-10-05  139.490005  142.240005  139.360001  141.110001  141.110001
# 2021-10-06  139.470001  142.149994  138.369995  142.000000  142.000000
# 2021-10-07  143.059998  144.220001  142.720001  143.289993  143.289993
# 2021-10-08  144.029999  144.179993  142.559998  142.899994  142.899994
#
#                Volume
# Date
# 2020-06-01   80791200
# 2020-06-02   87642800
# 2020-06-03  104491200
# 2020-06-04   87560400
# 2020-06-05  137250400
# ...               ...
# 2021-10-04   98322000
# 2021-10-05   80861100
# 2021-10-06   83221100
# 2021-10-07   61732700
# 2021-10-08   58718700
#
# [344 rows x 6 columns]

# %%
Cisco = yf.download(tickers='CSCO',start ='2020-5-31', end ='2021-10-10')
Cisco
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-06-01  47.150002  47.290001  46.230000  46.299999  44.221565  18712400
# 2020-06-02  46.400002  46.900002  45.880001  46.889999  44.785084  17285900
# 2020-06-03  46.980000  47.200001  46.540001  46.939999  44.832836  17492000
# 2020-06-04  46.770000  47.250000  46.529999  46.860001  44.756432  14100700
# 2020-06-05  47.270000  48.290001  47.200001  47.830002  45.682892  22591100
# ...               ...        ...        ...        ...        ...       ...
# 2021-10-04  54.500000  54.680000  53.950001  54.230000  54.230000  17084100
# 2021-10-05  54.130001  55.029999  54.130001  54.689999  54.689999  14135000
# 2021-10-06  54.349998  54.380001  52.980000  53.939999  53.939999  26339200
# 2021-10-07  54.490002  55.410000  54.349998  55.020000  55.020000  14725500
# 2021-10-08  55.200001  55.299999  54.750000  55.080002  55.080002   9255500
#
# [344 rows x 6 columns]

# %%
IBM = yf.download(tickers='IBM',start ='2020-5-31', end ='2021-10-10')
IBM
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-01  124.639999  125.750000  124.029999  124.889999  117.236809
# 2020-06-02  125.669998  126.000000  124.660004  126.000000  118.278793
# 2020-06-03  127.150002  129.600006  127.000000  129.050003  121.141891
# 2020-06-04  127.779999  128.949997  127.019997  128.889999  120.991684
# 2020-06-05  133.889999  134.229996  131.750000  132.059998  123.967445
# ...                ...         ...         ...         ...         ...
# 2021-10-04  142.740005  146.000000  142.350006  144.110001  144.110001
# 2021-10-05  144.750000  145.000000  142.639999  143.149994  143.149994
# 2021-10-06  142.479996  143.369995  140.889999  142.360001  142.360001
# 2021-10-07  142.729996  143.399994  141.529999  141.809998  141.809998
# 2021-10-08  141.809998  143.649994  141.050003  143.220001  143.220001
#
#              Volume
# Date
# 2020-06-01  2871700
# 2020-06-02  2978100
# 2020-06-03  3917700
# 2020-06-04  3864800
# 2020-06-05  5892700
# ...             ...
# 2021-10-04  7351100
# 2021-10-05  6976600
# 2021-10-06  5328400
# 2021-10-07  3823800
# 2021-10-08  3730700
#
# [344 rows x 6 columns]

# %%
AMZN = yf.download(tickers='AMZN',start ='2020-5-31', end ='2021-10-10')
AMZN
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-06-01  2448.000000  2476.929932  2444.169922  2471.040039  2471.040039
# 2020-06-02  2467.000000  2473.530029  2445.310059  2472.409912  2472.409912
# 2020-06-03  2468.010010  2488.000000  2461.169922  2478.399902  2478.399902
# 2020-06-04  2477.429932  2507.540039  2450.010010  2460.600098  2460.600098
# 2020-06-05  2444.510010  2488.649902  2437.129883  2483.000000  2483.000000
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  3279.389893  3279.989990  3176.250000  3189.780029  3189.780029
# 2021-10-05  3204.500000  3260.729980  3202.459961  3221.000000  3221.000000
# 2021-10-06  3213.530029  3264.340088  3198.620117  3262.010010  3262.010010
# 2021-10-07  3291.540039  3325.750000  3283.060059  3302.429932  3302.429932
# 2021-10-08  3317.000000  3321.429932  3288.199951  3288.620117  3288.620117
#
#              Volume
# Date
# 2020-06-01  2928900
# 2020-06-02  2529900
# 2020-06-03  2671000
# 2020-06-04  2948700
# 2020-06-05  3306400
# ...             ...
# 2021-10-04  4523100
# 2021-10-05  3269200
# 2021-10-06  2533000
# 2021-10-07  2409100
# 2021-10-08  1995500
#
# [344 rows x 6 columns]

# %%
AAPL.iloc[0]['Adj Close']
# Out:
# 79.80438995361328

# %%
for stock_df in (AAPL,Cisco,IBM,AMZN):
    stock_df['Normed Return'] = stock_df['Adj Close']/stock_df.iloc[0]['Adj Close']

# %%
df = pd.DataFrame(AAPL)

# %%
df[['Adj Close', 'Normed Return']].head()
# Out:
#             Adj Close  Normed Return
# Date
# 2020-06-01  79.804390       1.000000
# 2020-06-02  80.173859       1.004630
# 2020-06-03  80.615211       1.010160
# 2020-06-04  79.920937       1.001460
# 2020-06-05  82.197174       1.029983

# %%
df[['Adj Close', 'Normed Return']].tail()
# Out:
#              Adj Close  Normed Return
# Date
# 2021-10-04  139.139999       1.743513
# 2021-10-05  141.110001       1.768198
# 2021-10-06  142.000000       1.779351
# 2021-10-07  143.289993       1.795515
# 2021-10-08  142.899994       1.790628

# %%
# Allocation

# %%
# 30% in apple
# 20% in cisco
# 40% in amazon
# 10% in ibm

# %%
list(zip((AAPL,Cisco,IBM,AMZN), [.3,.2,.4,.1]))
# Out:
# [(                  Open        High         Low       Close   Adj Close  \
#   Date
#   2020-06-01   79.437500   80.587502   79.302498   80.462502   79.804390
#   2020-06-02   80.187500   80.860001   79.732498   80.834999   80.173859
#   2020-06-03   81.165001   81.550003   80.574997   81.279999   80.615211
#   2020-06-04   81.097504   81.404999   80.195000   80.580002   79.920937
#   2020-06-05   80.837502   82.937500   80.807503   82.875000   82.197174
#   ...                ...         ...         ...         ...         ...
#   2021-10-04  141.759995  142.210007  138.270004  139.139999  139.139999
#   2021-10-05  139.490005  142.240005  139.360001  141.110001  141.110001
#   2021-10-06  139.470001  142.149994  138.369995  142.000000  142.000000
#   2021-10-07  143.059998  144.220001  142.720001  143.289993  143.289993
#   2021-10-08  144.029999  144.179993  142.559998  142.899994  142.899994
#
#                  Volume  Normed Return
#   Date
#   2020-06-01   80791200       1.000000
#   2020-06-02   87642800       1.004630
#   2020-06-03  104491200       1.010160
#   2020-06-04   87560400       1.001460
#   2020-06-05  137250400       1.029983
#   ...               ...            ...
#   2021-10-04   98322000       1.743513
#   2021-10-05   80861100       1.768198
#   2021-10-06   83221100       1.779351
#   2021-10-07   61732700       1.795515
#   2021-10-08   58718700       1.790628
#
#   [344 rows x 7 columns],
#   0.3),
#  (                 Open       High        Low      Close  Adj Close    Volume  \
#   Date
#   2020-06-01  47.150002  47.290001  46.230000  46.299999  44.221565  18712400
#   2020-06-02  46.400002  46.900002  45.880001  46.889999  44.785084  17285900
#   2020-06-03  46.980000  47.200001  46.540001  46.939999  44.832836  17492000
#   2020-06-04  46.770000  47.250000  46.529999  46.860001  44.756432  14100700
#   2020-06-05  47.270000  48.290001  47.200001  47.830002  45.682892  22591100
#   ...               ...        ...        ...        ...        ...       ...
#   2021-10-04  54.500000  54.680000  53.950001  54.230000  54.230000  17084100
#   2021-10-05  54.130001  55.029999  54.130001  54.689999  54.689999  14135000
#   2021-10-06  54.349998  54.380001  52.980000  53.939999  53.939999  26339200
#   2021-10-07  54.490002  55.410000  54.349998  55.020000  55.020000  14725500
#   2021-10-08  55.200001  55.299999  54.750000  55.080002  55.080002   9255500
#
#               Normed Return
#   Date
#   2020-06-01       1.000000
#   2020-06-02       1.012743
#   2020-06-03       1.013823
#   2020-06-04       1.012095
#   2020-06-05       1.033046
#   ...                   ...
#   2021-10-04       1.226325
#   2021-10-05       1.236727
#   2021-10-06       1.219767
#   2021-10-07       1.244189
#   2021-10-08       1.245546
#
#   [344 rows x 7 columns],
#   0.2),
#  (                  Open        High         Low       Close   Adj Close  \
#   Date
#   2020-06-01  124.639999  125.750000  124.029999  124.889999  117.236809
#   2020-06-02  125.669998  126.000000  124.660004  126.000000  118.278793
#   2020-06-03  127.150002  129.600006  127.000000  129.050003  121.141891
#   2020-06-04  127.779999  128.949997  127.019997  128.889999  120.991684
#   2020-06-05  133.889999  134.229996  131.750000  132.059998  123.967445
#   ...                ...         ...         ...         ...         ...
#   2021-10-04  142.740005  146.000000  142.350006  144.110001  144.110001
#   2021-10-05  144.750000  145.000000  142.639999  143.149994  143.149994
#   2021-10-06  142.479996  143.369995  140.889999  142.360001  142.360001
#   2021-10-07  142.729996  143.399994  141.529999  141.809998  141.809998
#   2021-10-08  141.809998  143.649994  141.050003  143.220001  143.220001
#
#                Volume  Normed Return
#   Date
#   2020-06-01  2871700       1.000000
#   2020-06-02  2978100       1.008888
#   2020-06-03  3917700       1.033309
#   2020-06-04  3864800       1.032028
#   2020-06-05  5892700       1.057411
#   ...             ...            ...
#   2021-10-04  7351100       1.229221
#   2021-10-05  6976600       1.221033
#   2021-10-06  5328400       1.214294
#   2021-10-07  3823800       1.209603
#   2021-10-08  3730700       1.221630
#
#   [344 rows x 7 columns],
#   0.4),
#  (                   Open         High          Low        Close    Adj Close  \
#   Date
#   2020-06-01  2448.000000  2476.929932  2444.169922  2471.040039  2471.040039
#   2020-06-02  2467.000000  2473.530029  2445.310059  2472.409912  2472.409912
#   2020-06-03  2468.010010  2488.000000  2461.169922  2478.399902  2478.399902
#   2020-06-04  2477.429932  2507.540039  2450.010010  2460.600098  2460.600098
#   2020-06-05  2444.510010  2488.649902  2437.129883  2483.000000  2483.000000
#   ...                 ...          ...          ...          ...          ...
#   2021-10-04  3279.389893  3279.989990  3176.250000  3189.780029  3189.780029
#   2021-10-05  3204.500000  3260.729980  3202.459961  3221.000000  3221.000000
#   2021-10-06  3213.530029  3264.340088  3198.620117  3262.010010  3262.010010
#   2021-10-07  3291.540039  3325.750000  3283.060059  3302.429932  3302.429932
#   2021-10-08  3317.000000  3321.429932  3288.199951  3288.620117  3288.620117
#
#                Volume  Normed Return
#   Date
#   2020-06-01  2928900       1.000000
#   2020-06-02  2529900       1.000554
#   2020-06-03  2671000       1.002978
#   2020-06-04  2948700       0.995775
#   2020-06-05  3306400       1.004840
#   ...             ...            ...
#   2021-10-04  4523100       1.290865
#   2021-10-05  3269200       1.303500
#   2021-10-06  2533000       1.320096
#   2021-10-07  2409100       1.336453
#   2021-10-08  1995500       1.330865
#
#   [344 rows x 7 columns],
#   0.1)]

# %%
for stock_df, allo in zip((AAPL,Cisco,IBM,AMZN), [.3,.2,.4,.1]):
    stock_df['Allocation']= stock_df['Normed Return']*allo

# %%
AAPL[['Adj Close', 'Normed Return','Allocation']].head()
# Out:
#             Adj Close  Normed Return  Allocation
# Date
# 2020-06-01  79.804390       1.000000    0.300000
# 2020-06-02  80.173859       1.004630    0.301389
# 2020-06-03  80.615211       1.010160    0.303048
# 2020-06-04  79.920937       1.001460    0.300438
# 2020-06-05  82.197174       1.029983    0.308995

# %%
for stock_df in [AAPL,Cisco,IBM,AMZN]:
    stock_df['Position Values'] = stock_df['Allocation']*1000000

# %%
AAPL[['Adj Close', 'Normed Return','Allocation','Position Values' ]].head()
# Out:
#             Adj Close  Normed Return  Allocation  Position Values
# Date
# 2020-06-01  79.804390       1.000000    0.300000    300000.000000
# 2020-06-02  80.173859       1.004630    0.301389    301388.903627
# 2020-06-03  80.615211       1.010160    0.303048    303048.033574
# 2020-06-04  79.920937       1.001460    0.300438    300438.121127
# 2020-06-05  82.197174       1.029983    0.308995    308994.934189

# %%
all_pos_vals = [AAPL['Position Values'],Cisco['Position Values'],IBM['Position Values'],AMZN['Position Values'] ]
portfolio_val =pd.concat(all_pos_vals, axis=1)

# %%
portfolio_val.columns = ['AAPL Pos','CISCO Pos','IBM Pos','AMZN Pos']
portfolio_val.head()
# Out:
#                  AAPL Pos      CISCO Pos        IBM Pos       AMZN Pos
# Date
# 2020-06-01  300000.000000  200000.000000  400000.000000  100000.000000
# 2020-06-02  301388.903627  202548.614103  403555.144733  100055.437104
# 2020-06-03  303048.033574  202764.582851  413323.742751  100297.844760
# 2020-06-04  300438.121127  202419.029404  412811.250058   99577.508205
# 2020-06-05  308994.934189  206609.112956  422964.243626  100484.005146

# %%
portfolio_val['Total Pos'] = portfolio_val.sum(axis=1)
portfolio_val.head()
# Out:
#                  AAPL Pos      CISCO Pos        IBM Pos       AMZN Pos  \
# Date
# 2020-06-01  300000.000000  200000.000000  400000.000000  100000.000000
# 2020-06-02  301388.903627  202548.614103  403555.144733  100055.437104
# 2020-06-03  303048.033574  202764.582851  413323.742751  100297.844760
# 2020-06-04  300438.121127  202419.029404  412811.250058   99577.508205
# 2020-06-05  308994.934189  206609.112956  422964.243626  100484.005146
#
#                Total Pos
# Date
# 2020-06-01  1.000000e+06
# 2020-06-02  1.007548e+06
# 2020-06-03  1.019434e+06
# 2020-06-04  1.015246e+06
# 2020-06-05  1.039052e+06

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
portfolio_val['Total Pos'].plot(figsize=(12,6))
plt.title('Total Portfolio Value')
# Out:
# Text(0.5, 1.0, 'Total Portfolio Value')

# %%
portfolio_val.drop('Total Pos',axis=1).plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
portfolio_val.tail()
# Out:
#                  AAPL Pos      CISCO Pos        IBM Pos       AMZN Pos  \
# Date
# 2021-10-04  523053.930256  245264.948176  491688.581816  129086.537607
# 2021-10-05  530459.542485  247345.376952  488413.137103  130349.972039
# 2021-10-06  533805.220800  243953.366761  485717.760815  132009.597505
# 2021-10-07  538654.552849  248837.869718  483841.206659  133645.342829
# 2021-10-08  537188.470382  249109.236744  488651.994932  133086.476350
#
#                Total Pos
# Date
# 2021-10-04  1.389094e+06
# 2021-10-05  1.396568e+06
# 2021-10-06  1.395486e+06
# 2021-10-07  1.404979e+06
# 2021-10-08  1.408036e+06

# %%
#Portfolio Statistics & Sharpe Ratio

# %%
portfolio_val['Daily Return'] = portfolio_val['Total Pos'].pct_change(1)

# %%
portfolio_val.head()
# Out:
#                  AAPL Pos      CISCO Pos        IBM Pos       AMZN Pos  \
# Date
# 2020-06-01  300000.000000  200000.000000  400000.000000  100000.000000
# 2020-06-02  301388.903627  202548.614103  403555.144733  100055.437104
# 2020-06-03  303048.033574  202764.582851  413323.742751  100297.844760
# 2020-06-04  300438.121127  202419.029404  412811.250058   99577.508205
# 2020-06-05  308994.934189  206609.112956  422964.243626  100484.005146
#
#                Total Pos  Daily Return
# Date
# 2020-06-01  1.000000e+06           NaN
# 2020-06-02  1.007548e+06      0.007548
# 2020-06-03  1.019434e+06      0.011797
# 2020-06-04  1.015246e+06     -0.004108
# 2020-06-05  1.039052e+06      0.023449

# %%
cumulative_return = 100 * (portfolio_val['Total Pos'][-1]/portfolio_val['Total Pos'][0] -1 )
print('Our return {} was percent!'.format(cumulative_return))
# Out:
# Our return 40.80361784083064 was percent!

# %%
m = portfolio_val['Daily Return'].mean()
m
# Out:
# 0.0010783006856756288

# %%
std = portfolio_val['Daily Return'].std()
std
# Out:
# 0.012645261428549642

# %%
SR = m/std  #Sharpe ratio
SR
# Out:
# 0.08527310342838088

# %%
ASR = (252**0.5)*SR #Average sharpe ratio
ASR
# Out:
# 1.353668551165111

# %%
portfolio_val['Daily Return'].plot(kind ='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
all_stock_vals = [AAPL['Close'],Cisco['Close'],IBM['Close'],AMZN['Close'] ]
stocks = pd.concat(all_stock_vals,axis=1)
stocks.columns=['apple','cisco','ibm','amazon']
stocks.head()
# Out:
#                 apple      cisco         ibm       amazon
# Date
# 2020-06-01  80.462502  46.299999  124.889999  2471.040039
# 2020-06-02  80.834999  46.889999  126.000000  2472.409912
# 2020-06-03  81.279999  46.939999  129.050003  2478.399902
# 2020-06-04  80.580002  46.860001  128.889999  2460.600098
# 2020-06-05  82.875000  47.830002  132.059998  2483.000000

# %%
stocks.pct_change(1).mean() # mean of daily return
# Out:
# apple     0.001876
# cisco     0.000612
# ibm       0.000527
# amazon    0.001004
# dtype: float64

# %%
stocks_corr =stocks.pct_change(1).corr() #correlation
stocks_corr
# Out:
#            apple     cisco       ibm    amazon
# apple   1.000000  0.359836  0.137327  0.667072
# cisco   0.359836  1.000000  0.496536  0.245546
# ibm     0.137327  0.496536  1.000000  0.046643
# amazon  0.667072  0.245546  0.046643  1.000000

# %%
import seaborn as sns
sns.heatmap(stocks_corr,
            annot=True,
            cmap="YlGnBu", 
            linewidths=0.3,
            annot_kws={"size": 8})
plt.xticks(rotation=90)
plt.yticks(rotation=0) 
plt.show()

# %%
#Covariance

# %%
stocks_cov = stocks.pct_change(1).cov()
stocks_cov_annual = stocks_cov *252
stocks_cov_annual
# Out:
#            apple     cisco       ibm    amazon
# apple   0.101566  0.026298  0.011050  0.062479
# cisco   0.026298  0.052589  0.028749  0.016549
# ibm     0.011050  0.028749  0.063746  0.003461
# amazon  0.062479  0.016549  0.003461  0.086374

# %%
stock_daily_ret = stocks.pct_change(1)
stock_daily_ret.head()
# Out:
#                apple     cisco       ibm    amazon
# Date
# 2020-06-01       NaN       NaN       NaN       NaN
# 2020-06-02  0.004629  0.012743  0.008888  0.000554
# 2020-06-03  0.005505  0.001066  0.024206  0.002423
# 2020-06-04 -0.008612 -0.001704 -0.001240 -0.007182
# 2020-06-05  0.028481  0.020700  0.024595  0.009103

# %%
# log return

# %%
log_ret = np.log(stocks/stocks.shift(1))
log_ret.head()
# Out:
#                apple     cisco       ibm    amazon
# Date
# 2020-06-01       NaN       NaN       NaN       NaN
# 2020-06-02  0.004619  0.012662  0.008849  0.000554
# 2020-06-03  0.005490  0.001066  0.023918  0.002420
# 2020-06-04 -0.008649 -0.001706 -0.001241 -0.007208
# 2020-06-05  0.028083  0.020489  0.024297  0.009062

# %%
log_ret.hist(bins=100,figsize=(12,6));
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# apple   343.0  0.001675  0.020044 -0.083448 -0.008459  0.001509  0.013147
# cisco   343.0  0.000506  0.014601 -0.118615 -0.006316  0.000410  0.007948
# ibm     343.0  0.000399  0.016068 -0.104306 -0.007825  0.000768  0.008253
# amazon  343.0  0.000833  0.018486 -0.078663 -0.009005  0.001233  0.010880
#
#              max
# apple   0.099564
# cisco   0.068217
# ibm     0.058085
# amazon  0.076308

# %%
log_ret.mean() * 252
# Out:
# apple     0.421974
# cisco     0.127576
# ibm       0.100615
# amazon    0.209997
# dtype: float64

# %%
log_ret.cov() #covariance
# Out:
#            apple     cisco       ibm    amazon
# apple   0.000402  0.000105  0.000045  0.000248
# cisco   0.000105  0.000213  0.000116  0.000066
# ibm     0.000045  0.000116  0.000258  0.000015
# amazon  0.000248  0.000066  0.000015  0.000342

# %%
log_ret.cov()*252 # multiply by days
# Out:
#            apple     cisco       ibm    amazon
# apple   0.101240  0.026495  0.011328  0.062609
# cisco   0.026495  0.053725  0.029251  0.016696
# ibm     0.011328  0.029251  0.065058  0.003697
# amazon  0.062609  0.016696  0.003697  0.086118

# %%
#Optimal Portfolio

# %%
number = 15000 #simulation number

np.random.seed(101)

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)


for ind in range(number):
    
    weights = np.array(np.random.random(4))
    
    weights = weights / np.sum(weights)
    
    all_weights[ind,:] = weights
    
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)
    
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
    
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]

# %%
sharpe_arr.max()
# Out:
# 1.3425952255453393

# %%
sharpe_arr.argmax()
# Out:
# 9659

# %%
all_weights[9659,:]
# Out:
# array([8.25707379e-01, 1.44853910e-04, 1.72202148e-01, 1.94561948e-03])

# %%
max_sr_ret = ret_arr[9659]
max_sr_vol = vol_arr[9659]

# %%
plt.figure(figsize=(12,6))
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

plt.scatter(max_sr_vol,max_sr_ret,c='red',s=50,edgecolors='black')
