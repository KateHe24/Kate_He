# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/peiqinhe/Desktop/python-master'

# %%
df = pd.read_excel('../Excel exerices.xls')

# %%
df
# Out:
#         SEI Released Matched Cusip DTCC Cusip Payable Date    Position  \
# 0                              NaN        NaN          NaN         NaN
# 1     Kate-Cusip 0-9 Interest only        NaN          NaN         NaN
# 2                           Posted  004375DZ1  Apr-25-2020    562272.0
# 3                           Posted  004421CT8  Apr-25-2020   1000000.0
# 4                           Posted  004421DE0  Apr-25-2020   2000000.0
# ...                            ...        ...          ...         ...
# 1440                 Released-Paid  94989UAG6  Apr-25-2020   8530000.0
# 1441                 Released-Paid  95001TAA3  Apr-25-2020  15000000.0
# 1442                 Released-Paid  95002KAA1  Apr-25-2020  12000000.0
# 1443                 Released-Paid  971885AL2  Apr-25-2020   5912000.0
# 1444                 Released-Paid  971885AN8  Apr-25-2020   7578000.0
#
#       DTC Interest - cash rate  DTC prior factor  DTC current factor  \
# ...

# %%
df['Principal Amount'].isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1440    False
# 1441    False
# 1442    False
# 1443    False
# 1444    False
# Name: Principal Amount, Length: 1445, dtype: bool

# %%
x = df[(~ df['Principal Amount'].isna()) & (~ df['Interest Amount'].isna())& (df['Principal Amount']>0)]
x
# Out:
#      SEI Released Matched Cusip DTCC Cusip Payable Date    Position  \
# 340                         NaN  00434MAC1  Apr-25-2020   7500000.0
# 341                         NaN  004421CR2  Apr-25-2020   1760000.0
# 343                         NaN  004421QQ9  Apr-25-2020   1829000.0
# 345                         NaN  007037AE4  Apr-25-2020  17530465.0
# 346                         NaN  008684AA0  Apr-25-2020  15130000.0
# ...                         ...        ...          ...         ...
# 1440              Released-Paid  94989UAG6  Apr-25-2020   8530000.0
# 1441              Released-Paid  95001TAA3  Apr-25-2020  15000000.0
# 1442              Released-Paid  95002KAA1  Apr-25-2020  12000000.0
# 1443              Released-Paid  971885AL2  Apr-25-2020   5912000.0
# 1444              Released-Paid  971885AN8  Apr-25-2020   7578000.0
#
#       DTC Interest - cash rate  DTC prior factor  DTC current factor  \
# 340                   0.760002          0.474682            0.466959
# ...

# %%
x['Difference'] = x['Principal Amount']-x['Position']*(x['DTC prior factor']-x['DTC current factor'])
x = x.loc[x['Difference']>0.1]
x
# Out:
#     SEI Released Matched Cusip DTCC Cusip Payable Date    Position  \
# 345                        NaN  007037AE4  Apr-25-2020  17530465.0
# 351                        NaN  02146XAH1  Apr-25-2020   2100000.0
# 358                        NaN  02660WAB2  Apr-25-2020   5000000.0
# 359                        NaN  02660XAA2  Apr-25-2020   1323000.0
# 373                        NaN  05530MAA7  Apr-25-2020   4693548.0
# 419                        NaN  07386HRU7  Apr-25-2020   5350000.0
# 420                        NaN  07386HYW5  Apr-25-2020  58905069.0
# 421                        NaN  073870AA5  Apr-25-2020   5000000.0
# 428                        NaN  07401LAR4  Apr-25-2020  15090000.0
# 430                        NaN  07401NAB5  Apr-25-2020  30900000.0
# 459                        NaN  12667GA37  Apr-25-2020   4800000.0
# 463                        NaN  12668ALK9  Apr-25-2020   9961000.0
# 465                        NaN  12668AX75  Apr-25-2020   4019000.0
# ...

# %%
x.to_excel('Excel_Update.xlsx')
